# %%
num = 10
num
# Out:
# 10

# %%
type(num)
# Out:
# int

# %%
    age = int(input("enter the age"))
    if age > 18:
        print("eligible")
    else:
        print("not eligible")
# Out:
# not eligible

# %%
import numpy as np 
import pandas as pd
