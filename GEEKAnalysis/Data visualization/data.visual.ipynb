# %%
import pandas as pd
import numpy as np 
df = pd.read_csv('AB_NYC_2019.csv')
df
# Out:
#          id                                              name  host_id  \
# 0      2539                Clean & quiet apt home by the park     2787
# 1      2595                             Skylit Midtown Castle     2845
# 2      3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3      3831                   Cozy Entire Floor of Brownstone     4869
# 4      5022  Entire Apt: Spacious Studio/Loft by central park     7192
# ...     ...                                               ...      ...
# 48901  5441                   Central Manhattan/near Broadway     7989
# 48902  5803    Lovely Room 1, Garden, Best Area, Legal rental     9744
# 48903  6021  Wonderful Guest Bedroom in Manhattan for SINGLES    11528
# 48904  6090                     West Village Nest - Superhost    11975
# 48905  6848                  Only 2 stops to Manhattan studio    15991
#
#            host_name neighbourhood_group    neighbourhood  latitude  \
# ...

# %%
df["id"]=df["id"].astype(str)
df["host_id"]=df["host_id"].astype(str)
df["latitude"]=df["latitude"].astype(str)
df["longitude"]=df["longitude"].astype(str)
df
# Out:
#          id                                              name host_id  \
# 0      2539                Clean & quiet apt home by the park    2787
# 1      2595                             Skylit Midtown Castle    2845
# 2      3647               THE VILLAGE OF HARLEM....NEW YORK !    4632
# 3      3831                   Cozy Entire Floor of Brownstone    4869
# 4      5022  Entire Apt: Spacious Studio/Loft by central park    7192
# ...     ...                                               ...     ...
# 48901  5441                   Central Manhattan/near Broadway    7989
# 48902  5803    Lovely Room 1, Garden, Best Area, Legal rental    9744
# 48903  6021  Wonderful Guest Bedroom in Manhattan for SINGLES   11528
# 48904  6090                     West Village Nest - Superhost   11975
# 48905  6848                  Only 2 stops to Manhattan studio   15991
#
#            host_name neighbourhood_group    neighbourhood  latitude  \
# ...

# %%
df.describe()
# Out:
#               price  minimum_nights  number_of_reviews  reviews_per_month  \
# count  48906.000000    48906.000000       48906.000000       38854.000000
# mean     152.711324        7.031612          23.300454           1.373151
# std      240.128713       20.512489          44.607175           1.680270
# min        0.000000        1.000000           0.000000           0.010000
# 25%       69.000000        1.000000           1.000000           0.190000
# 50%      106.000000        3.000000           5.000000           0.720000
# 75%      175.000000        5.000000          24.000000           2.020000
# max    10000.000000     1250.000000         629.000000          58.500000
#
#        calculated_host_listings_count  availability_365
# count                    48906.000000      48906.000000
# mean                         7.142702        112.782031
# std                         32.948926        131.620370
# min                          1.000000          0.000000
# ...

# %%
df.nunique()
# Out:
# id                                48895
# name                              47896
# host_id                           37457
# host_name                         11452
# neighbourhood_group                   5
# neighbourhood                       221
# latitude                          19048
# longitude                         14718
# room_type                             3
# price                               674
# minimum_nights                      109
# number_of_reviews                   394
# last_review                        1764
# reviews_per_month                   937
# calculated_host_listings_count       47
# availability_365                    366
# dtype: int64

# %% [markdown]
# Categorical data set . categorical data gives the base information of the presence of major hotels .

# %%
df["neighbourhood"].value_counts(normalize= True)
# Out:
# neighbourhood
# Williamsburg          0.080174
# Bedford-Stuyvesant    0.075962
# Harlem                0.054349
# Bushwick              0.050403
# Upper West Side       0.040363
#                         ...
# Fort Wadsworth        0.000020
# Richmondtown          0.000020
# New Dorp              0.000020
# Rossville             0.000020
# Willowbrook           0.000020
# Name: proportion, Length: 221, dtype: float64

# %%
df_n = (df["price"] > 1000).reset_index()
df_n
# Out:
#        index  price
# 0          0  False
# 1          1  False
# 2          2  False
# 3          3  False
# 4          4  False
# ...      ...    ...
# 48901  48901  False
# 48902  48902  False
# 48903  48903  False
# 48904  48904  False
# 48905  48905  False
#
# [48906 rows x 2 columns]
